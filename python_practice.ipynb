# %%
name = 'rohit chandrakant mehta'
#if i want chandrakant output
value = name[6:17]
print (value)
# Out:
# chandrakant

# %%
bank = 'state bank of india'
#if i want india output
branch = bank[14:19]
print(branch)
# Out:
# india

# %%
switchtech = 'ram,jay,shekhar,chanchal,ashwini,shubham,baburao'
#if i want shekhar and shubham output
student = switchtech[8:15] +" "+ switchtech[33:40]
print(student)
# Out:
# shekhar shubham

# %%
bank = 'hdfc,sbi,kotak,axis,icici,cosmos,sawji,'
#i want jay name with axis bank
ac_holder_name ='ram,jay,chanchal,shubham,akshay,ashish,sangita,ashwini'
bank_details = ac_holder_name[4:7] + ' ' + bank[15:19] 
print(bank_details)
# Out:
# jay axis
