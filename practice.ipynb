# %%
#Cash withdrawal
  
amount= 'withdrawal amount'
current_balance='100000'
verify_user_password=True
pin =12345
card =True
#ATM insert card

if card is True:
    #enter pin
    if pin == 12345:
        print("verify user password")
        """will show ("withdrawal", "balance","deposit", "change pin", "etc.")
        need insert user input for withdrawal
        then insert amount and press Yes"""
        int(input("Enter withdrawal amount"))
        if amount> '5 INR'  and amount<= 'current_balance':
            print ("withdrawal successful")
            #will  give money 
        else:
            print ("withdrawal failed")
            #will not give money
    else:
        print("invalid pin")
        #will not show any option
else:
    print("invalid card")
    #will not show any option
# Out:
# verify user password
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 17
#      13 print("verify user password")
#      14 """will show ("withdrawal", "balance","deposit", "change pin", "etc.")
#      15 need insert user input for withdrawal
#      16 then insert amount and press Yes"""
# ---> 17 int(input("Enter withdrawal amount"))
#      18 if amount> '5 INR'  and amount<= 'current_balance':
#      19     print ("withdrawal successful")
#
# ValueError: invalid literal for int() with base 10: ''
